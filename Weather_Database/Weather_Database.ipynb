# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 730

# %%
# cities = cities[:20]

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Date": city_date,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | andros town
# Processing Record 2 of Set 1 | clyde river
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | lakatoro
# Processing Record 11 of Set 1 | ambilobe
# Processing Record 12 of Set 1 | naze
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | solwezi
# Processing Record 15 of Set 1 | cervo
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | porto novo
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | cidreira
# Processing Record 21 of Set 1 | mnogovershinnyy
# Processing Record 22 of Set 1 | flinders
# Processing Record 23 of Set 1 | arraial do cabo
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | paamiut
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | nikolskoye
# Processing Record 28 of Set 1 | sisimiut
# Processing Record 29 of Set 1 | sandakan
# Processing Record 30 of Set 1 | bengkulu
# Processing Record 31 of Set 1 | la ronge
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | jijiang
# Processing Record 35 of Set 1 | jinchengjiang
# City not found. Skipping...
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | miri
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | makakilo city
# Processing Record 44 of Set 1 | mataura
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | hasaki
# Processing Record 48 of Set 1 | yumen
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | eskil
# Processing Record 1 of Set 2 | vestmanna
# Processing Record 2 of Set 2 | talnakh
# Processing Record 3 of Set 2 | voh
# Processing Record 4 of Set 2 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 2 | kutum
# Processing Record 6 of Set 2 | marzuq
# Processing Record 7 of Set 2 | beringovskiy
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | komsomolskiy
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | port elizabeth
# Processing Record 12 of Set 2 | saskylakh
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | mar del plata
# Processing Record 15 of Set 2 | nishihara
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | faanui
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | shitanjing
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | bay roberts
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | qasigiannguit
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | cedar city
# Processing Record 27 of Set 2 | sharkan
# Processing Record 28 of Set 2 | broome
# Processing Record 29 of Set 2 | klaksvik
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | loukhi
# Processing Record 32 of Set 2 | buariki
# City not found. Skipping...
# Processing Record 33 of Set 2 | mount isa
# Processing Record 34 of Set 2 | sept-iles
# Processing Record 35 of Set 2 | ostrovnoy
# Processing Record 36 of Set 2 | fortuna
# Processing Record 37 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 2 | ngunguru
# Processing Record 39 of Set 2 | hilo
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 2 | takaka
# Processing Record 43 of Set 2 | north platte
# Processing Record 44 of Set 2 | bentiu
# Processing Record 45 of Set 2 | meadow lake
# Processing Record 46 of Set 2 | kontagora
# Processing Record 47 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 2 | tolga
# Processing Record 49 of Set 2 | pisco
# Processing Record 50 of Set 2 | aksarka
# Processing Record 1 of Set 3 | haines junction
# Processing Record 2 of Set 3 | badaojiang
# City not found. Skipping...
# Processing Record 3 of Set 3 | quatre cocos
# Processing Record 4 of Set 3 | beyneu
# Processing Record 5 of Set 3 | krasnoturansk
# Processing Record 6 of Set 3 | cape town
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | otjiwarongo
# Processing Record 11 of Set 3 | bulawayo
# Processing Record 12 of Set 3 | urucara
# Processing Record 13 of Set 3 | gazli
# Processing Record 14 of Set 3 | negombo
# Processing Record 15 of Set 3 | san cristobal
# Processing Record 16 of Set 3 | normandin
# Processing Record 17 of Set 3 | severo-kurilsk
# Processing Record 18 of Set 3 | khatanga
# Processing Record 19 of Set 3 | bairiki
# Processing Record 20 of Set 3 | erzin
# Processing Record 21 of Set 3 | moerai
# Processing Record 22 of Set 3 | sur
# Processing Record 23 of Set 3 | sitka
# Processing Record 24 of Set 3 | serebryansk
# Processing Record 25 of Set 3 | amurzet
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | lucapa
# Processing Record 29 of Set 3 | san mateo del mar
# Processing Record 30 of Set 3 | waingapu
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | doctor arroyo
# Processing Record 33 of Set 3 | okha
# Processing Record 34 of Set 3 | bara
# Processing Record 35 of Set 3 | sinegorye
# Processing Record 36 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 3 | iganga
# Processing Record 38 of Set 3 | isfana
# Processing Record 39 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 3 | ketchikan
# Processing Record 41 of Set 3 | antalaha
# Processing Record 42 of Set 3 | thai binh
# Processing Record 43 of Set 3 | brigantine
# Processing Record 44 of Set 3 | saint-gilles
# Processing Record 45 of Set 3 | hobart
# Processing Record 46 of Set 3 | carutapera
# Processing Record 47 of Set 3 | dingle
# Processing Record 48 of Set 3 | mahebourg
# Processing Record 49 of Set 3 | saint-augustin
# Processing Record 50 of Set 3 | taoudenni
# Processing Record 1 of Set 4 | puerto rico
# Processing Record 2 of Set 4 | snyder
# Processing Record 3 of Set 4 | culleredo
# Processing Record 4 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 4 | isla aguada
# Processing Record 6 of Set 4 | idah
# Processing Record 7 of Set 4 | srednekolymsk
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | oakley
# Processing Record 11 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | airai
# Processing Record 14 of Set 4 | cutlerville
# Processing Record 15 of Set 4 | new norfolk
# Processing Record 16 of Set 4 | ilulissat
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | chokurdakh
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | te anau
# Processing Record 21 of Set 4 | valparaiso
# Processing Record 22 of Set 4 | kismayo
# Processing Record 23 of Set 4 | atar
# Processing Record 24 of Set 4 | lavrentiya
# Processing Record 25 of Set 4 | hualmay
# Processing Record 26 of Set 4 | ust-maya
# Processing Record 27 of Set 4 | muisne
# Processing Record 28 of Set 4 | balkanabat
# Processing Record 29 of Set 4 | bajil
# Processing Record 30 of Set 4 | novyy urgal
# Processing Record 31 of Set 4 | mayo
# Processing Record 32 of Set 4 | sibu
# Processing Record 33 of Set 4 | acurenam
# Processing Record 34 of Set 4 | huarmey
# Processing Record 35 of Set 4 | shingu
# Processing Record 36 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 4 | sinjar
# Processing Record 38 of Set 4 | katra
# Processing Record 39 of Set 4 | abha
# Processing Record 40 of Set 4 | ballina
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | ust-tsilma
# Processing Record 43 of Set 4 | mutare
# Processing Record 44 of Set 4 | katsuura
# Processing Record 45 of Set 4 | san jose
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | padang
# Processing Record 48 of Set 4 | zeya
# Processing Record 49 of Set 4 | norman wells
# Processing Record 50 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 1 of Set 5 | nanortalik
# Processing Record 2 of Set 5 | mengcheng
# Processing Record 3 of Set 5 | lyons
# Processing Record 4 of Set 5 | helmsdale
# Processing Record 5 of Set 5 | alice springs
# Processing Record 6 of Set 5 | trento
# Processing Record 7 of Set 5 | puerto ayora
# Processing Record 8 of Set 5 | port hardy
# Processing Record 9 of Set 5 | portland
# Processing Record 10 of Set 5 | bako
# Processing Record 11 of Set 5 | lagoa
# Processing Record 12 of Set 5 | ambon
# Processing Record 13 of Set 5 | panguna
# Processing Record 14 of Set 5 | oyama
# Processing Record 15 of Set 5 | almaznyy
# Processing Record 16 of Set 5 | lorengau
# Processing Record 17 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 5 | upernavik
# Processing Record 19 of Set 5 | san luis
# Processing Record 20 of Set 5 | panaba
# Processing Record 21 of Set 5 | chuy
# Processing Record 22 of Set 5 | oni
# Processing Record 23 of Set 5 | svetlogorsk
# Processing Record 24 of Set 5 | tuktoyaktuk
# Processing Record 25 of Set 5 | deming
# Processing Record 26 of Set 5 | souillac
# Processing Record 27 of Set 5 | isangel
# Processing Record 28 of Set 5 | coaraci
# Processing Record 29 of Set 5 | puerto escondido
# Processing Record 30 of Set 5 | chicama
# Processing Record 31 of Set 5 | laguna
# Processing Record 32 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 5 | waddan
# Processing Record 34 of Set 5 | davila
# Processing Record 35 of Set 5 | ponta do sol
# Processing Record 36 of Set 5 | raton
# Processing Record 37 of Set 5 | den helder
# Processing Record 38 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 5 | hamilton
# Processing Record 40 of Set 5 | aksay
# Processing Record 41 of Set 5 | abu samrah
# Processing Record 42 of Set 5 | sioux lookout
# Processing Record 43 of Set 5 | igurubi
# Processing Record 44 of Set 5 | necochea
# Processing Record 45 of Set 5 | dicabisagan
# Processing Record 46 of Set 5 | port blair
# Processing Record 47 of Set 5 | the valley
# Processing Record 48 of Set 5 | turayf
# Processing Record 49 of Set 5 | bethel
# Processing Record 50 of Set 5 | almeria
# Processing Record 1 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 6 | spas-klepiki
# Processing Record 3 of Set 6 | zonguldak
# Processing Record 4 of Set 6 | santa rosa
# Processing Record 5 of Set 6 | fairbanks
# Processing Record 6 of Set 6 | meulaboh
# Processing Record 7 of Set 6 | anloga
# Processing Record 8 of Set 6 | kavaratti
# Processing Record 9 of Set 6 | ulladulla
# Processing Record 10 of Set 6 | namatanai
# Processing Record 11 of Set 6 | gazanjyk
# Processing Record 12 of Set 6 | salinas
# Processing Record 13 of Set 6 | san matias
# Processing Record 14 of Set 6 | ellington
# Processing Record 15 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 6 | goundam
# Processing Record 17 of Set 6 | kemijarvi
# Processing Record 18 of Set 6 | luanda
# Processing Record 19 of Set 6 | kudahuvadhoo
# Processing Record 20 of Set 6 | big spring
# Processing Record 21 of Set 6 | zhengjiatun
# Processing Record 22 of Set 6 | dannenberg
# Processing Record 23 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 24 of Set 6 | cuamba
# Processing Record 25 of Set 6 | kenora
# Processing Record 26 of Set 6 | lagos
# Processing Record 27 of Set 6 | qaqortoq
# Processing Record 28 of Set 6 | saint-pierre
# Processing Record 29 of Set 6 | novopavlovka
# Processing Record 30 of Set 6 | suntar
# Processing Record 31 of Set 6 | merrill
# Processing Record 32 of Set 6 | constitucion
# Processing Record 33 of Set 6 | itum-kale
# Processing Record 34 of Set 6 | guerrero negro
# Processing Record 35 of Set 6 | kidal
# Processing Record 36 of Set 6 | biankouma
# Processing Record 37 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 38 of Set 6 | iqaluit
# Processing Record 39 of Set 6 | arlit
# Processing Record 40 of Set 6 | bandarbeyla
# Processing Record 41 of Set 6 | coihaique
# Processing Record 42 of Set 6 | avera
# Processing Record 43 of Set 6 | kruisfontein
# Processing Record 44 of Set 6 | sao filipe
# Processing Record 45 of Set 6 | luderitz
# Processing Record 46 of Set 6 | anandpur sahib
# Processing Record 47 of Set 6 | misratah
# Processing Record 48 of Set 6 | vostok
# Processing Record 49 of Set 6 | yurkivka
# Processing Record 50 of Set 6 | angoche
# Processing Record 1 of Set 7 | bat khela
# Processing Record 2 of Set 7 | bambous virieux
# Processing Record 3 of Set 7 | wuzhou
# Processing Record 4 of Set 7 | sobolevo
# Processing Record 5 of Set 7 | mukhen
# Processing Record 6 of Set 7 | caravelas
# Processing Record 7 of Set 7 | moussoro
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | novolvovsk
# City not found. Skipping...
# Processing Record 10 of Set 7 | manokwari
# Processing Record 11 of Set 7 | camacha
# Processing Record 12 of Set 7 | platteville
# Processing Record 13 of Set 7 | labelle
# Processing Record 14 of Set 7 | nantucket
# Processing Record 15 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 16 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 7 | touros
# Processing Record 18 of Set 7 | riyadh
# Processing Record 19 of Set 7 | najran
# Processing Record 20 of Set 7 | labuhan
# Processing Record 21 of Set 7 | hoa binh
# Processing Record 22 of Set 7 | muleba
# Processing Record 23 of Set 7 | preobrazheniye
# Processing Record 24 of Set 7 | chapais
# Processing Record 25 of Set 7 | yenagoa
# Processing Record 26 of Set 7 | tamandare
# Processing Record 27 of Set 7 | provideniya
# Processing Record 28 of Set 7 | bayir
# Processing Record 29 of Set 7 | vao
# Processing Record 30 of Set 7 | bom jesus
# Processing Record 31 of Set 7 | shunyi
# Processing Record 32 of Set 7 | pahalgam
# Processing Record 33 of Set 7 | chifeng
# Processing Record 34 of Set 7 | cap malheureux
# Processing Record 35 of Set 7 | gazimurskiy zavod
# Processing Record 36 of Set 7 | maceio
# Processing Record 37 of Set 7 | wanning
# Processing Record 38 of Set 7 | magadan
# Processing Record 39 of Set 7 | le port
# Processing Record 40 of Set 7 | henties bay
# Processing Record 41 of Set 7 | menongue
# Processing Record 42 of Set 7 | krasnoselkup
# Processing Record 43 of Set 7 | egvekinot
# Processing Record 44 of Set 7 | sahuaripa
# Processing Record 45 of Set 7 | kalmunai
# Processing Record 46 of Set 7 | gambo
# Processing Record 47 of Set 7 | londoko
# Processing Record 48 of Set 7 | moindou
# Processing Record 49 of Set 7 | hawalli
# Processing Record 50 of Set 7 | yelabuga
# Processing Record 1 of Set 8 | qui nhon
# Processing Record 2 of Set 8 | kununurra
# Processing Record 3 of Set 8 | digby
# Processing Record 4 of Set 8 | tuatapere
# Processing Record 5 of Set 8 | mount gambier
# Processing Record 6 of Set 8 | kamaishi
# Processing Record 7 of Set 8 | araria
# Processing Record 8 of Set 8 | mehamn
# Processing Record 9 of Set 8 | rocha
# Processing Record 10 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 8 | atambua
# Processing Record 12 of Set 8 | gao
# Processing Record 13 of Set 8 | vallenar
# Processing Record 14 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 15 of Set 8 | las vegas
# Processing Record 16 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 8 | zyryanka
# Processing Record 18 of Set 8 | sangar
# Processing Record 19 of Set 8 | bilma
# Processing Record 20 of Set 8 | jadu
# Processing Record 21 of Set 8 | olafsvik
# Processing Record 22 of Set 8 | itoman
# Processing Record 23 of Set 8 | kincardine
# Processing Record 24 of Set 8 | husavik
# Processing Record 25 of Set 8 | murray bridge
# Processing Record 26 of Set 8 | dudinka
# Processing Record 27 of Set 8 | mahon
# Processing Record 28 of Set 8 | ushtobe
# Processing Record 29 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 8 | ajdabiya
# Processing Record 31 of Set 8 | thunder bay
# Processing Record 32 of Set 8 | tessalit
# Processing Record 33 of Set 8 | samarai
# Processing Record 34 of Set 8 | taltal
# Processing Record 35 of Set 8 | ortona
# Processing Record 36 of Set 8 | sibolga
# Processing Record 37 of Set 8 | cayenne
# Processing Record 38 of Set 8 | port keats
# Processing Record 39 of Set 8 | honiara
# Processing Record 40 of Set 8 | celestun
# Processing Record 41 of Set 8 | boquira
# Processing Record 42 of Set 8 | richards bay
# Processing Record 43 of Set 8 | kingston
# Processing Record 44 of Set 8 | varkkallai
# Processing Record 45 of Set 8 | bethanien
# Processing Record 46 of Set 8 | bilibino
# Processing Record 47 of Set 8 | cockburn town
# Processing Record 48 of Set 8 | buchanan
# Processing Record 49 of Set 8 | kahului
# Processing Record 50 of Set 8 | grand gaube
# Processing Record 1 of Set 9 | gazojak
# Processing Record 2 of Set 9 | tongchuan
# Processing Record 3 of Set 9 | borogontsy
# Processing Record 4 of Set 9 | el cobre
# Processing Record 5 of Set 9 | saint-joseph
# Processing Record 6 of Set 9 | ardakan
# Processing Record 7 of Set 9 | manado
# Processing Record 8 of Set 9 | mugango
# Processing Record 9 of Set 9 | daloa
# Processing Record 10 of Set 9 | bonavista
# Processing Record 11 of Set 9 | bouake
# Processing Record 12 of Set 9 | narayangarh
# Processing Record 13 of Set 9 | coos bay
# Processing Record 14 of Set 9 | sembakung
# Processing Record 15 of Set 9 | luwuk
# Processing Record 16 of Set 9 | hay river
# Processing Record 17 of Set 9 | palana
# Processing Record 18 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 19 of Set 9 | san policarpo
# Processing Record 20 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 9 | hami
# Processing Record 22 of Set 9 | marawi
# Processing Record 23 of Set 9 | pacific grove
# Processing Record 24 of Set 9 | namibe
# Processing Record 25 of Set 9 | narsaq
# Processing Record 26 of Set 9 | saldanha
# Processing Record 27 of Set 9 | tiksi
# Processing Record 28 of Set 9 | matay
# Processing Record 29 of Set 9 | sarangani
# Processing Record 30 of Set 9 | port lincoln
# Processing Record 31 of Set 9 | moyale
# Processing Record 32 of Set 9 | pavullo nel frignano
# Processing Record 33 of Set 9 | vagur
# Processing Record 34 of Set 9 | viedma
# Processing Record 35 of Set 9 | mahibadhoo
# Processing Record 36 of Set 9 | tupik
# Processing Record 37 of Set 9 | zarate
# Processing Record 38 of Set 9 | victoria
# Processing Record 39 of Set 9 | whitefish
# Processing Record 40 of Set 9 | sabha
# Processing Record 41 of Set 9 | zhigalovo
# Processing Record 42 of Set 9 | tura
# Processing Record 43 of Set 9 | northam
# Processing Record 44 of Set 9 | matagami
# Processing Record 45 of Set 9 | coracora
# Processing Record 46 of Set 9 | caraballeda
# Processing Record 47 of Set 9 | yaan
# Processing Record 48 of Set 9 | nome
# Processing Record 49 of Set 9 | rundu
# Processing Record 50 of Set 9 | tuy hoa
# Processing Record 1 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 2 of Set 10 | dakar
# Processing Record 3 of Set 10 | oum hadjer
# Processing Record 4 of Set 10 | cravo norte
# Processing Record 5 of Set 10 | filadelfia
# Processing Record 6 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 10 | plettenberg bay
# Processing Record 8 of Set 10 | leningradskiy
# Processing Record 9 of Set 10 | north creek
# Processing Record 10 of Set 10 | bemidji
# Processing Record 11 of Set 10 | gravdal
# Processing Record 12 of Set 10 | chama
# Processing Record 13 of Set 10 | nemuro
# Processing Record 14 of Set 10 | scarborough
# Processing Record 15 of Set 10 | beloha
# Processing Record 16 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 10 | karratha
# Processing Record 18 of Set 10 | ulan-ude
# Processing Record 19 of Set 10 | san angelo
# Processing Record 20 of Set 10 | alta floresta
# Processing Record 21 of Set 10 | awjilah
# Processing Record 22 of Set 10 | evensk
# Processing Record 23 of Set 10 | shambu
# Processing Record 24 of Set 10 | zhigansk
# Processing Record 25 of Set 10 | ahipara
# Processing Record 26 of Set 10 | mingshui
# Processing Record 27 of Set 10 | sandpoint
# Processing Record 28 of Set 10 | nangomba
# Processing Record 29 of Set 10 | paungde
# Processing Record 30 of Set 10 | xichang
# Processing Record 31 of Set 10 | muros
# Processing Record 32 of Set 10 | smithers
# Processing Record 33 of Set 10 | hofn
# Processing Record 34 of Set 10 | manggar
# Processing Record 35 of Set 10 | marsabit
# Processing Record 36 of Set 10 | lichuan
# Processing Record 37 of Set 10 | oktyabrskiy
# Processing Record 38 of Set 10 | corner brook
# Processing Record 39 of Set 10 | hirara
# Processing Record 40 of Set 10 | port macquarie
# Processing Record 41 of Set 10 | noto
# Processing Record 42 of Set 10 | adiake
# Processing Record 43 of Set 10 | latung
# Processing Record 44 of Set 10 | gat
# Processing Record 45 of Set 10 | debre tabor
# Processing Record 46 of Set 10 | westport
# Processing Record 47 of Set 10 | suez
# Processing Record 48 of Set 10 | havre-saint-pierre
# Processing Record 49 of Set 10 | sao felix do xingu
# Processing Record 50 of Set 10 | horsham
# Processing Record 1 of Set 11 | los llanos de aridane
# Processing Record 2 of Set 11 | presidente epitacio
# Processing Record 3 of Set 11 | vinh
# Processing Record 4 of Set 11 | quincy
# Processing Record 5 of Set 11 | kegayli
# City not found. Skipping...
# Processing Record 6 of Set 11 | udachnyy
# Processing Record 7 of Set 11 | mpika
# Processing Record 8 of Set 11 | johi
# Processing Record 9 of Set 11 | catamarca
# Processing Record 10 of Set 11 | barcelos
# Processing Record 11 of Set 11 | gori
# Processing Record 12 of Set 11 | nyrob
# Processing Record 13 of Set 11 | taunggyi
# Processing Record 14 of Set 11 | zhangjiakou
# Processing Record 15 of Set 11 | valer
# Processing Record 16 of Set 11 | yulara
# Processing Record 17 of Set 11 | bambanglipuro
# Processing Record 18 of Set 11 | chimbote
# Processing Record 19 of Set 11 | dubbo
# Processing Record 20 of Set 11 | buin
# Processing Record 21 of Set 11 | mecca
# Processing Record 22 of Set 11 | moosomin
# Processing Record 23 of Set 11 | honningsvag
# Processing Record 24 of Set 11 | the pas
# Processing Record 25 of Set 11 | pasni
# Processing Record 26 of Set 11 | deputatskiy
# Processing Record 27 of Set 11 | rudnogorsk
# Processing Record 28 of Set 11 | ures
# Processing Record 29 of Set 11 | sungaipenuh
# Processing Record 30 of Set 11 | chumikan
# Processing Record 31 of Set 11 | oistins
# Processing Record 32 of Set 11 | areosa
# Processing Record 33 of Set 11 | novikovo
# Processing Record 34 of Set 11 | navoi
# Processing Record 35 of Set 11 | takoradi
# Processing Record 36 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 11 | oktyabrskoye
# Processing Record 38 of Set 11 | tyrma
# Processing Record 39 of Set 11 | andenes
# Processing Record 40 of Set 11 | genhe
# Processing Record 41 of Set 11 | prince rupert
# Processing Record 42 of Set 11 | santa rosalia
# Processing Record 43 of Set 11 | broken hill
# Processing Record 44 of Set 11 | diamantino
# Processing Record 45 of Set 11 | puerto montt
# Processing Record 46 of Set 11 | sukhaya buyvola
# Processing Record 47 of Set 11 | kita
# Processing Record 48 of Set 11 | roald
# Processing Record 49 of Set 11 | finschhafen
# Processing Record 50 of Set 11 | fare
# Processing Record 1 of Set 12 | aklavik
# Processing Record 2 of Set 12 | boende
# Processing Record 3 of Set 12 | kupino
# Processing Record 4 of Set 12 | chippewa falls
# Processing Record 5 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 12 | nanchang
# Processing Record 7 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 12 | san quintin
# Processing Record 9 of Set 12 | kaeo
# Processing Record 10 of Set 12 | manzhouli
# Processing Record 11 of Set 12 | charleston
# Processing Record 12 of Set 12 | novobiryusinskiy
# Processing Record 13 of Set 12 | vestmannaeyjar
# Processing Record 14 of Set 12 | ilhabela
# Processing Record 15 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 12 | kalofer
# Processing Record 17 of Set 12 | yar-sale
# Processing Record 18 of Set 12 | sarny
# Processing Record 19 of Set 12 | road town
# Processing Record 20 of Set 12 | manbij
# Processing Record 21 of Set 12 | weiser
# Processing Record 22 of Set 12 | tantangan
# Processing Record 23 of Set 12 | bridlington
# Processing Record 24 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 25 of Set 12 | kunda
# Processing Record 26 of Set 12 | hervey bay
# Processing Record 27 of Set 12 | pingliang
# Processing Record 28 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 12 | roros
# Processing Record 30 of Set 12 | tual
# Processing Record 31 of Set 12 | lagoa vermelha
# Processing Record 32 of Set 12 | guiratinga
# Processing Record 33 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 12 | antofagasta
# Processing Record 35 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 36 of Set 12 | ciudad bolivar
# Processing Record 37 of Set 12 | hope
# Processing Record 38 of Set 12 | puerto pinasco
# City not found. Skipping...
# Processing Record 39 of Set 12 | piranhas
# Processing Record 40 of Set 12 | cali
# Processing Record 41 of Set 12 | talcahuano
# Processing Record 42 of Set 12 | mana
# Processing Record 43 of Set 12 | jefferson city
# Processing Record 44 of Set 12 | kimbe
# Processing Record 45 of Set 12 | mirnyy
# Processing Record 46 of Set 12 | saint anthony
# Processing Record 47 of Set 12 | taihe
# Processing Record 48 of Set 12 | madang
# Processing Record 49 of Set 12 | emba
# Processing Record 50 of Set 12 | vung tau
# Processing Record 1 of Set 13 | zhanaozen
# Processing Record 2 of Set 13 | kaili
# Processing Record 3 of Set 13 | samana
# Processing Record 4 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 5 of Set 13 | sandwick
# Processing Record 6 of Set 13 | krasnyy chikoy
# Processing Record 7 of Set 13 | floresta
# Processing Record 8 of Set 13 | zatoka
# Processing Record 9 of Set 13 | pandan niog
# Processing Record 10 of Set 13 | sergeyevka
# Processing Record 11 of Set 13 | pasaje
# Processing Record 12 of Set 13 | abilene
# Processing Record 13 of Set 13 | longyearbyen
# Processing Record 14 of Set 13 | whyalla
# Processing Record 15 of Set 13 | bartica
# Processing Record 16 of Set 13 | caconda
# Processing Record 17 of Set 13 | zhezkazgan
# Processing Record 18 of Set 13 | velikie luki
# City not found. Skipping...
# Processing Record 19 of Set 13 | bacalar
# Processing Record 20 of Set 13 | havixbeck
# Processing Record 21 of Set 13 | adrar
# Processing Record 22 of Set 13 | khipro
# Processing Record 23 of Set 13 | ballitoville
# Processing Record 24 of Set 13 | muhos
# Processing Record 25 of Set 13 | faya
# Processing Record 26 of Set 13 | nouadhibou
# Processing Record 27 of Set 13 | lethem
# Processing Record 28 of Set 13 | codrington
# Processing Record 29 of Set 13 | kolokani
# Processing Record 30 of Set 13 | letterkenny
# Processing Record 31 of Set 13 | seydi
# Processing Record 32 of Set 13 | key west
# Processing Record 33 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 34 of Set 13 | ulaangom
# Processing Record 35 of Set 13 | lyuban
# Processing Record 36 of Set 13 | coahuayana
# Processing Record 37 of Set 13 | eureka
# Processing Record 38 of Set 13 | belmonte
# Processing Record 39 of Set 13 | sao joao da barra
# Processing Record 40 of Set 13 | chase
# Processing Record 41 of Set 13 | san juan
# Processing Record 42 of Set 13 | vila franca do campo
# Processing Record 43 of Set 13 | naica
# Processing Record 44 of Set 13 | challans
# Processing Record 45 of Set 13 | fort nelson
# Processing Record 46 of Set 13 | belyy yar
# Processing Record 47 of Set 13 | katrineholm
# Processing Record 48 of Set 13 | tautira
# Processing Record 49 of Set 13 | kahramanmaras
# Processing Record 50 of Set 13 | uige
# Processing Record 1 of Set 14 | omsukchan
# Processing Record 2 of Set 14 | asau
# Processing Record 3 of Set 14 | baykit
# Processing Record 4 of Set 14 | ulukulevo
# Processing Record 5 of Set 14 | serowe
# Processing Record 6 of Set 14 | jiujiang
# Processing Record 7 of Set 14 | sorland
# Processing Record 8 of Set 14 | tubmanburg
# Processing Record 9 of Set 14 | migori
# Processing Record 10 of Set 14 | milkovo
# Processing Record 11 of Set 14 | kangaatsiaq
# Processing Record 12 of Set 14 | terenos
# Processing Record 13 of Set 14 | lata
# Processing Record 14 of Set 14 | dalvik
# Processing Record 15 of Set 14 | belaya gora
# Processing Record 16 of Set 14 | conway
# Processing Record 17 of Set 14 | ler
# Processing Record 18 of Set 14 | nhulunbuy
# Processing Record 19 of Set 14 | urdoma
# Processing Record 20 of Set 14 | tezu
# Processing Record 21 of Set 14 | flin flon
# Processing Record 22 of Set 14 | cabra
# Processing Record 23 of Set 14 | merritt island
# Processing Record 24 of Set 14 | marsh harbour
# Processing Record 25 of Set 14 | grindavik
# Processing Record 26 of Set 14 | vigia
# Processing Record 27 of Set 14 | port augusta
# Processing Record 28 of Set 14 | sangmelima
# Processing Record 29 of Set 14 | shahr-e babak
# Processing Record 30 of Set 14 | daru
# Processing Record 31 of Set 14 | amazar
# Processing Record 32 of Set 14 | bereda
# Processing Record 33 of Set 14 | maun
# Processing Record 34 of Set 14 | izumo
# Processing Record 35 of Set 14 | bagn
# Processing Record 36 of Set 14 | rawson
# Processing Record 37 of Set 14 | lasa
# Processing Record 38 of Set 14 | aksu
# Processing Record 39 of Set 14 | batagay-alyta
# Processing Record 40 of Set 14 | ashington
# Processing Record 41 of Set 14 | eyl
# Processing Record 42 of Set 14 | tahoua
# Processing Record 43 of Set 14 | akdepe
# Processing Record 44 of Set 14 | magadi
# Processing Record 45 of Set 14 | libreville
# Processing Record 46 of Set 14 | bageshwar
# Processing Record 47 of Set 14 | noumea
# Processing Record 48 of Set 14 | banjarmasin
# Processing Record 49 of Set 14 | lahaina
# Processing Record 50 of Set 14 | manaus
# Processing Record 1 of Set 15 | acapulco
# Processing Record 2 of Set 15 | nan
# Processing Record 3 of Set 15 | bonthe
# Processing Record 4 of Set 15 | sapatgram
# Processing Record 5 of Set 15 | campbellton
# Processing Record 6 of Set 15 | katherine
# Processing Record 7 of Set 15 | abu zabad
# Processing Record 8 of Set 15 | bitung
# Processing Record 9 of Set 15 | yingcheng
# Processing Record 10 of Set 15 | kunyang
# Processing Record 11 of Set 15 | buala
# Processing Record 12 of Set 15 | fukue
# Processing Record 13 of Set 15 | minab
# Processing Record 14 of Set 15 | fushun
# Processing Record 15 of Set 15 | arapiraca
# Processing Record 16 of Set 15 | timbiqui
# Processing Record 17 of Set 15 | thoen
# Processing Record 18 of Set 15 | sharya
# Processing Record 19 of Set 15 | maubin
# Processing Record 20 of Set 15 | sheoganj
# Processing Record 21 of Set 15 | khandyga
# Processing Record 22 of Set 15 | yazman
# Processing Record 23 of Set 15 | lewiston
# Processing Record 24 of Set 15 | fatehpur
# Processing Record 25 of Set 15 | urusha
# Processing Record 26 of Set 15 | guarapari
# Processing Record 27 of Set 15 | eqbaliyeh
# Processing Record 28 of Set 15 | osoyoos
# Processing Record 29 of Set 15 | tamworth
# Processing Record 30 of Set 15 | imeni poliny osipenko
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0   Andros Town      BS  2022-01-13 02:47:59  24.7000  -77.7667     69.76
# 1   Clyde River      CA  2022-01-13 02:48:00  70.4692  -68.5914    -30.77
# 2        Albany      US  2022-01-13 02:48:00  42.6001  -73.9662     32.61
# 3        Kodiak      US  2022-01-13 02:48:00  57.7900 -152.4072     29.71
# 4      Hermanus      ZA  2022-01-13 02:48:01 -34.4187   19.2345     68.90
# 5       Rikitea      PF  2022-01-13 02:48:01 -23.1203 -134.9692     77.07
# 6       Qaanaaq      GL  2022-01-13 02:48:01  77.4840  -69.3632     -2.79
# 7  Punta Arenas      CL  2022-01-13 02:48:01 -53.1500  -70.9167     46.51
# 8      Lakatoro      VU  2022-01-13 02:48:02 -16.0999  167.4164     86.77
# 9      Ambilobe      MG  2022-01-13 02:48:02 -13.2000   49.0500     75.31
#
#    Humidity  Cloudiness  Wind Speed Weather Description
# 0        75          85       12.97     overcast clouds
# 1        68           0        2.30           clear sky
# 2        67         100        2.82     overcast clouds
# 3        86           0        0.00           clear sky
# 4        82         100       17.00     overcast clouds
# 5        75           6       19.22          light rain
# 6        96         100        2.42     overcast clouds
# 7        57          40       11.50    scattered clouds
# 8        59           4        6.80           clear sky
# 9        94         100        1.52     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
